# %% [markdown]
# ### The diagram below shows a dataset with 2 classes and 8 data points, each with only one feature f value, labeled f. Note that there are two data points with the same feature value of 6. These ### are shown as two x’s one above the other.

# %% [markdown]
# ![Dataset Image](dataset.jpg)

# %% [markdown]
# ##### Assuming DOT as Dog
# ##### Assuming CROSS as Cat
#
# #### every Data point lies on X plane so each datapoint has (value, 0) as coordinates (Having single feature 'f')
#
# ##### Data points for DOG
# ##### [(1,0), (2,0), (7,0), (10,0), (11,0)]
# ##### Cat Data Points
# ##### [(3,1), (6,1), (6,1)]

# %%
# Importing required modules
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix

# %%
#data_points = [[1,0],[2,0],[3,1],[6,1],[6,1],[7,0],[10,0],[11,0]]
# initilizing X and Y values
x = [[1],[2],[3],[6],[6],[7],[10],[11]]
y = [0,0,1,1,1,0,0,0]

# %%
# splitting data
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.5, random_state=33)

# %%
## Training Model with train data
classifier = KNeighborsClassifier(n_neighbors=3,p=2,metric='euclidean')
classifier.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(metric='euclidean', n_neighbors=3)

# %%
# predicting Values from trained model
y_pred = classifier.predict(x_test)
y_pred
# Out:
# array([1, 1, 1, 1])

# %%
# calculating Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[0, 3],
#        [0, 1]], dtype=int64)

# %%
## Assigning True positives, ture negatives and false positives, false negatives
## Calculating Accuracy, Sensitivity, Specificity
TP = cm[0][0]
TN = cm[1][1]
FP = cm[1][0]
FN = cm[0][1]
Accuracy = (TP+TN)/4
print("Accuracy is: ",Accuracy)
Sensitivity  = TP/(TP+FN)
print("Sensitivity is: ",Sensitivity)
Specificity = TN/(FP+TN)
print("Specificity is: ",Specificity)
# Out:
# Accuracy is:  0.25
# Sensitivity is:  0.0
# Specificity is:  1.0
