# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
# Importing Required Libraries
import pandas as pd
import numpy as np
import scipy.cluster.hierarchy as shc
from sklearn.preprocessing import StandardScaler, Normalizer
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import silhouette_score
from sklearn.decomposition import PCA

# %%
# Importing Dataset
df = pd.read_csv('/content/gdrive/MyDrive/Datasets/CC_GENERAL.csv')
df.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
# Getting Statical view of data
df.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %%
# Dropping Catogoricaldata
df = df.drop(['CUST_ID'],axis=1)

# %%
# check for null values
df.isnull().sum()
# Out:
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
# filling null values using mean of data
df['CREDIT_LIMIT'] = df['CREDIT_LIMIT'].fillna(np.mean(df['CREDIT_LIMIT']))
df['MINIMUM_PAYMENTS'] = df['MINIMUM_PAYMENTS'].fillna(np.mean(df['MINIMUM_PAYMENTS']))
df.isnull().sum()
# Out:
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %%
# SCaling data using Standard Scaler
scale = StandardScaler()
scaled_df = pd.DataFrame(scale.fit_transform(df), columns=df.columns)
scaled_df.head()
# Out:
#     BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0 -0.731989          -0.249434  -0.424900         -0.356934
# 1  0.786961           0.134325  -0.469552         -0.356934
# 2  0.447135           0.518084  -0.107668          0.108889
# 3  0.049099          -1.016953   0.232058          0.546189
# 4 -0.358775           0.518084  -0.462063         -0.347294
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0               -0.349079     -0.466786            -0.806490
# 1               -0.454576      2.605605            -1.221758
# 2               -0.454576     -0.466786             1.269843
# 3               -0.454576     -0.368653            -1.014125
# 4               -0.454576     -0.466786            -1.014125
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                   -0.678661                         -0.707313
# 1                   -0.678661                         -0.916995
# ...

# %%
# Normalizing data
normalize = Normalizer()
norm_df = pd.DataFrame(normalize.fit_transform(scaled_df), columns=scaled_df.columns)
norm_df.head()
# Out:
#     BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0 -0.311938          -0.106297  -0.181072         -0.152108
# 1  0.219925           0.037539  -0.131222         -0.099749
# 2  0.126682           0.146783  -0.030504          0.030850
# 3  0.020589          -0.426439   0.097309          0.229034
# 4 -0.151595           0.218909  -0.195238         -0.146744
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0               -0.148760     -0.198921            -0.343687
# 1               -0.127037      0.728166            -0.341434
# 2               -0.128790     -0.132249             0.359771
# 3               -0.190618     -0.154587            -0.425253
# 4               -0.192075     -0.197234            -0.428504
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                   -0.289212                         -0.301422
# 1                   -0.189660                         -0.256265
# ...

# %%
norm_df.describe()
# Out:
#            BALANCE  BALANCE_FREQUENCY    PURCHASES  ONEOFF_PURCHASES  \
# count  8950.000000        8950.000000  8950.000000       8950.000000
# mean     -0.036517           0.020765    -0.042853         -0.035385
# std       0.244663           0.295141     0.156043          0.152297
# min      -0.483286          -0.909587    -0.298688         -0.268728
# 25%      -0.206007           0.011609    -0.152266         -0.130623
# 50%      -0.110904           0.135002    -0.089667         -0.086978
# 75%       0.074168           0.207875     0.015296         -0.002794
# max       0.854700           0.427439     0.603604          0.749526
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean                -0.036301     -0.039530            -0.023762
# std                  0.184492      0.205965             0.324395
# min                 -0.311007     -0.333097            -0.580187
# ...

# %%
# Correlation Heatmap of Dataset
f, ax = plt.subplots(figsize = (15,10))
sns.heatmap(norm_df.corr(),annot = True)

# %%
# applying PCA for data
pca = PCA(n_components=2)
x_pca = pca.fit_transform(norm_df)
pca_df = pd.DataFrame(data=x_pca, columns=['P1', 'P2'])

# %%
# Applying Agglomatrive Algorithm and visualizing using scatter plot
from sklearn.cluster import AgglomerativeClustering
ac2 = AgglomerativeClustering(n_clusters = 2)

# Visualizing the clustering
plt.figure(figsize =(6, 6))
plt.scatter(pca_df['P1'], pca_df['P2'],
c = ac2.fit_predict(pca_df), cmap ='rainbow')
plt.show()

# %%
ac3 = AgglomerativeClustering(n_clusters = 3)

plt.figure(figsize =(6, 6))
plt.scatter(pca_df['P1'], pca_df['P2'],
c = ac3.fit_predict(pca_df), cmap ='rainbow')
plt.show()

# %%
ac4 = AgglomerativeClustering(n_clusters = 4)

plt.figure(figsize =(6, 6))
plt.scatter(pca_df['P1'], pca_df['P2'],
c = ac4.fit_predict(pca_df), cmap ='rainbow')
plt.show()

# %%
ac5 = AgglomerativeClustering(n_clusters = 5)

plt.figure(figsize =(6, 6))
plt.scatter(pca_df['P1'], pca_df['P2'],
c = ac5.fit_predict(pca_df), cmap ='rainbow')
plt.show()

# %%
k = [2,3,4,5]
silhouette_scores = []
silhouette_scores.append(
silhouette_score(pca_df, ac2.fit_predict(pca_df)))
silhouette_scores.append(
silhouette_score(pca_df, ac3.fit_predict(pca_df)))
silhouette_scores.append(
silhouette_score(pca_df, ac4.fit_predict(pca_df)))
silhouette_scores.append(
silhouette_score(pca_df, ac5.fit_predict(pca_df)))

# %%
# plotting silhouttee_scores using barchart
plt.bar(k, silhouette_scores)
plt.xlabel('Number of clusters', fontsize = 20)
plt.ylabel('S(i)', fontsize = 20)
plt.show()
